# %%
# Import PuLP modeler functions
from pulp import *

# %%
impos=["aa","bb","cc","dd","ee","ff","gg","hh","ii","jj","kk","ll","mm"]
impt=["aa","bb","cc","dd"]
max_paper_positions=4

# %%
#create list of all possible tables
possible_tables = [tuple(c) for c in pulp.allcombinations(impos, max_paper_positions)]

# %%
possible_tables
# Out:
# [('aa',),
#  ('bb',),
#  ('cc',),
#  ('dd',),
#  ('ee',),
#  ('ff',),
#  ('gg',),
#  ('hh',),
#  ('ii',),
#  ('jj',),
#  ('kk',),
#  ('ll',),
#  ('mm',),
#  ('aa', 'bb'),
#  ('aa', 'cc'),
#  ('aa', 'dd'),
#  ('aa', 'ee'),
#  ('aa', 'ff'),
#  ('aa', 'gg'),
#  ('aa', 'hh'),
#  ('aa', 'ii'),
#  ('aa', 'jj'),
#  ('aa', 'kk'),
#  ('aa', 'll'),
#  ('aa', 'mm'),
#  ('bb', 'cc'),
#  ('bb', 'dd'),
#  ('bb', 'ee'),
#  ('bb', 'ff'),
#  ('bb', 'gg'),
#  ('bb', 'hh'),
#  ('bb', 'ii'),
#  ('bb', 'jj'),
#  ('bb', 'kk'),
#  ('bb', 'll'),
#  ('bb', 'mm'),
#  ('cc', 'dd'),
#  ('cc', 'ee'),
#  ('cc', 'ff'),
#  ('cc', 'gg'),
#  ('cc', 'hh'),
#  ('cc', 'ii'),
#  ('cc', 'jj'),
#  ('cc', 'kk'),
#  ('cc', 'll'),
#  ('cc', 'mm'),
#  ('dd', 'ee'),
#  ('dd', 'ff'),
#  ('dd', 'gg'),
#  ('dd', 'hh'),
#  ('dd', 'ii'),
#  ('dd', 'jj'),
#  ('dd', 'kk'),
#  ('dd', 'll'),
#  ('dd', 'mm'),
#  ('ee', 'ff'),
#  ('ee', 'gg'),
#  ('ee', 'hh'),
#  ('ee', 'ii'),
#  ('ee', 'jj'),
#  ('ee', 'kk'),
#  ('ee', 'll'),
# ...

# %%
import itertools as itt

# %%
fin=0
possible_impose= [x for x in itt.combinations_with_replacement(impt, 9)]
len(possible_impose)
# Out:
# 220

# %%
print(possible_impose)
# Out:
# [('aa', 'aa', 'aa', 'aa', 'aa', 'aa', 'aa', 'aa', 'aa'), ('aa', 'aa', 'aa', 'aa', 'aa', 'aa', 'aa', 'aa', 'bb'), ('aa', 'aa', 'aa', 'aa', 'aa', 'aa', 'aa', 'aa', 'cc'), ('aa', 'aa', 'aa', 'aa', 'aa', 'aa', 'aa', 'aa', 'dd'), ('aa', 'aa', 'aa', 'aa', 'aa', 'aa', 'aa', 'bb', 'bb'), ('aa', 'aa', 'aa', 'aa', 'aa', 'aa', 'aa', 'bb', 'cc'), ('aa', 'aa', 'aa', 'aa', 'aa', 'aa', 'aa', 'bb', 'dd'), ('aa', 'aa', 'aa', 'aa', 'aa', 'aa', 'aa', 'cc', 'cc'), ('aa', 'aa', 'aa', 'aa', 'aa', 'aa', 'aa', 'cc', 'dd'), ('aa', 'aa', 'aa', 'aa', 'aa', 'aa', 'aa', 'dd', 'dd'), ('aa', 'aa', 'aa', 'aa', 'aa', 'aa', 'bb', 'bb', 'bb'), ('aa', 'aa', 'aa', 'aa', 'aa', 'aa', 'bb', 'bb', 'cc'), ('aa', 'aa', 'aa', 'aa', 'aa', 'aa', 'bb', 'bb', 'dd'), ('aa', 'aa', 'aa', 'aa', 'aa', 'aa', 'bb', 'cc', 'cc'), ('aa', 'aa', 'aa', 'aa', 'aa', 'aa', 'bb', 'cc', 'dd'), ('aa', 'aa', 'aa', 'aa', 'aa', 'aa', 'bb', 'dd', 'dd'), ('aa', 'aa', 'aa', 'aa', 'aa', 'aa', 'cc', 'cc', 'cc'), ('aa', 'aa', 'aa', 'aa', 'aa', 'aa', 'cc', 'c
# ...

# %%
from sys import getsizeof

# %%
getsizeof(possible_impose)
# Out:
# 1936

# %%
impositions = pulp.LpVariable.dicts('imposition', possible_impose, 
                            lowBound = 0,
                            upBound = 1,
                            cat = pulp.LpInteger)

imprints = [14000,15000,16000]
costs = {
    "desky":500,
        
    }

# %%
imposing_model = pulp.LpProblem("Imposing Model", pulp.LpMinimize)

# %%
imposing_model += sum([happiness(table) * impositions[table] for table in possible_impose])
